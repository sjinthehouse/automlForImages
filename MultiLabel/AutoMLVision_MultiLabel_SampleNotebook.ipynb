# %% [markdown]
# Copyright (c) Microsoft Corporation. All rights reserved.
#
# Licensed under the MIT License.
#
# # Training an Multi-Label Classification model using AutoML Vision
# In this notebook, we go over how you can use AutoML Vision for training a Multi-Label Classification model. We will use a small dataset to train the model, demonstrate how you can tune hyperparameters of the model to optimize model performance and deploy the model to use in inference scenarios.

# %% [markdown]
# ## Setup
# To use this notebook, you will need to install the private preview package for AutoML Vision from the private index.
#
# In the example below replace 34635915 by the latest build number:

# %%
# !pip install azureml-train==0.1.0.34635915 azureml-train-automl==0.1.0.34635915 azureml-contrib-dataset==0.1.0.34635915 --extra-index-url https://azuremlsdktestpypi.azureedge.net/automl-vision-tests/34635915

# %% [markdown]
# ### Licensing Information -
# This preview software is made available to you on the condition that you agree to
# [your agreement][1] governing your use of Azure, and to the Supplemental Terms of Use for Microsoft Azure Previews[2], which supplement your agreement governing your use of Azure.
# If you do not have an existing agreement governing your use of Azure, you agree that
# your agreement governing use of Azure is the [Microsoft Online Subscription Agreement][3]
# (which incorporates the [Online Services Terms][4]).
# By using the software you agree to these terms. This software may collect data
# that is transmitted to Microsoft. Please see the [Microsoft Privacy Statement][5]
# to learn more about how Microsoft processes personal data.
#
# [1]: https://azure.microsoft.com/en-us/support/legal/
# [2]: https://azure.microsoft.com/en-us/support/legal/preview-supplemental-terms/
# [3]: https://azure.microsoft.com/en-us/support/legal/subscription-agreement/
# [4]: http://www.microsoftvolumelicensing.com/DocumentSearch.aspx?Mode=3&DocumentTypeId=46
# [5]: http://go.microsoft.com/fwlink/?LinkId=248681

# %% [markdown]
# ## Workspace setup
# In order to train and deploy models in Azure ML, you will first need to set up a workspace.
#
# An [Azure ML Workspace](https://docs.microsoft.com/en-us/azure/machine-learning/concept-azure-machine-learning-architecture#workspace) is an Azure resource that organizes and coordinates the actions of many other Azure resources to assist in executing and sharing machine learning workflows. In particular, an Azure ML Workspace coordinates storage, databases, and compute resources providing added functionality for machine learning experimentation, deployment, inference, and the monitoring of deployed models.
#
# Create an Azure ML Workspace within your Azure subscription, or load an existing workspace.

# %%
## specify workspace parameters
#//TODO - remove the IDs before publishing
subscription_id='dbd697c3-ef40-488f-83e6-5ad4dfb78f9b'   
resource_group='alwangeu21'   
workspace_name='alwangeu21'

#subscription_id='<my-subscription-id>'   
#resource_group='<my-resource-group>'   
#workspace_name='<my-workspace-name>'

from azureml.core.workspace import Workspace
ws = Workspace.create(name = workspace_name,
                      subscription_id = subscription_id,
                      resource_group = resource_group, 
                      exist_ok = True)

# %% [markdown]
# ## Compute target setup
# You will need to provide a [Compute Target](https://docs.microsoft.com/azure/machine-learning/service/concept-azure-machine-learning-architecture#compute-target) that will be used for your AutoML model training. AutoML Vision models require GPU SKUs and support NC and ND families. Using a compute target with a multi-GPU VM SKU will leverage the multiple GPUs to speed up training. Additionally, setting up a compute target with multiple nodes will allow for faster model training by leveraging parallelism, when tuning hyperparameters for your model.

# %%
from azureml.core.compute import AmlCompute, ComputeTarget

cluster_name = "nc6cluster"

try:
    compute_target = ws.compute_targets[cluster_name]
    print('Found existing compute target.')
except KeyError:
    print('Creating a new compute target...')
    compute_config = AmlCompute.provisioning_configuration(vm_size='Standard_NC6', 
                                                           idle_seconds_before_scaledown=1800,
                                                           min_nodes=0, 
                                                           max_nodes=4)

    compute_target = ComputeTarget.create(ws, cluster_name, compute_config)
    compute_target.wait_for_completion(show_output = True, min_node_count = None, timeout_in_minutes = 20)
# Out:
# Found existing compute target.

# %% [markdown]
# ## Experiment Setup
# Create an [Experiment](https://docs.microsoft.com/azure/machine-learning/service/concept-azure-machine-learning-architecture#experiment) in your workspace to track your model training runs

# %%
from azureml.core import Experiment

experiment_name = 'automl-vision-notebook' 
experiment = Experiment(ws, name=experiment_name)

# %% [markdown]
# ## Dataset with input Training Data
# In order to generate Vision models, you will need to bring in labeled image data as input for model training in the form of an AzureML Labeled Dataset. You can either use a Labeled Dataset that you have exported from a Data Labeling project, or create a new Labeled Dataset with your labeled training data

# %% [markdown]
# In this notebook, we use a toy dataset called Fridge Objects, which consists of 128 images. It also include a labels file in .csv format.
#
# This is one of the most common data formats for multi-label image classification; one csv file that contains the mapping of labels to a folder of images.
#
# We first download and unzip the data locally.

# %%
import os
import urllib
from zipfile import ZipFile

# download data
download_url = 'https://cvbp-secondary.z19.web.core.windows.net/datasets/image_classification/multilabelFridgeObjects.zip'
data_file = './multilabelFridgeObjects.zip'
urllib.request.urlretrieve(download_url, filename=data_file)

# extract files
with ZipFile(data_file, 'r') as zip:
    print('extracting files...')
    zip.extractall()
    print('done')
    
# delete zip file
os.remove(data_file)
# Out:
# extracting files...
# done

# %% [markdown]
# This is a sample image from this dataset:

# %%
from IPython.display import Image
sample_image ='./multilabelFridgeObjects/images/56.jpg';
Image(filename=sample_image)

# %% [markdown]
# ### Convert the downloaded data to JSONL
# In this example, the fridge object dataset is annotated in the CSV file, where each image corresponds to a line. It defines a mapping of the filename to the labels. Since this is a multi-label classification problem, each image can be associated to multiple labels. In order to use this data to create an AzureML Datset, we first need to convert it to the required JSONL format.
#
# The following script is creating two .jsonl files (one for training and one for validation) in the parent folder of the dataset. The train / validation ration corresponds to 20% of the data going into the validation file.

# %%
import json
import os
import xml.etree.ElementTree as ET

src = "./multilabelFridgeObjects"
train_validation_ratio = 5

# Retrieving default datastore that got automatically created when we setup a workspace
workspaceblobstore = ws.get_default_datastore().name

# Path to the labels file.
labelFile = os.path.join(src, "labels.csv")

# Path to the training and validation files
train_annotations_file = os.path.join(src, "train_annotations.jsonl")
validation_annotations_file = os.path.join(src, "validation_annotations.jsonl")

# sample json line dictionary
json_line_sample = \
    {
        "image_url": "AmlDatastore://" + workspaceblobstore + "/multilabelFridgeObjects",
        "label": []
    }

# Read each annotation and convert it to jsonl line
with open(train_annotations_file, 'w') as train_f:
    with open(validation_annotations_file, 'w') as validation_f:
        with open(labelFile, 'r') as labels:
            for i, line in enumerate(labels):
                # Skipping the title line and any empty lines.
                if (i == 0 or len(line.strip()) == 0):
                    continue
                line_split = line.strip().split(",")
                if len(line_split) != 2:
                    print("Skipping the invalid line: {}".format(line))
                    continue
                json_line = dict(json_line_sample)
                json_line["image_url"] += f"/images/{line_split[0]}"
                json_line["label"] = line_split[1].strip().split(" ")

                if i % train_validation_ratio == 0:
                    # validation annotation
                    validation_f.write(json.dumps(json_line) + "\n")
                else:
                    # train annotation
                    train_f.write(json.dumps(json_line) + "\n")

# %% [markdown]
# ### Upload the JSONL file and images to Datastore
# In order to use the data for training in Azure ML, we upload it to our Azure ML Workspace via a [Datastore](https://docs.microsoft.com/en-us/azure/machine-learning/concept-azure-machine-learning-architecture#datasets-and-datastores). The datastore provides a mechanism for you to upload/download data, and interact with it from your remote compute targets. It is an abstraction over Azure Storage.

# %%
# Retrieving default datastore that got automatically created when we setup a workspace
ds = ws.get_default_datastore()
ds.upload(src_dir='./multilabelFridgeObjects', target_path='multilabelFridgeObjects')
# Out:
# Uploading an estimated of 131 files
# Uploading ./multilabelFridgeObjects\labels.csv
# Uploaded ./multilabelFridgeObjects\labels.csv, 1 files out of an estimated total of 131
# Uploading ./multilabelFridgeObjects\train_annotations.jsonl
# Uploaded ./multilabelFridgeObjects\train_annotations.jsonl, 2 files out of an estimated total of 131
# Uploading ./multilabelFridgeObjects\validation_annotations.jsonl
# Uploaded ./multilabelFridgeObjects\validation_annotations.jsonl, 3 files out of an estimated total of 131
# Uploading ./multilabelFridgeObjects\images\1.jpg
# Uploaded ./multilabelFridgeObjects\images\1.jpg, 4 files out of an estimated total of 131
# Uploading ./multilabelFridgeObjects\images\10.jpg
# Uploaded ./multilabelFridgeObjects\images\10.jpg, 5 files out of an estimated total of 131
# Uploading ./multilabelFridgeObjects\images\100.jpg
# Uploaded ./multilabelFridgeObjects\images\100.jpg, 6 files out of an estimated total of 131
# Uploading ./multilabelFridgeObjects\images\101.jpg
# Uploaded ./multilabelFridgeObjects\images\101.jpg, 7 files out of an estimated total of 131
# Uploading ./multilabelFridgeObjects\images\102.jpg
# Uploaded ./multilabelFridgeObjects\images\102.jpg, 8 files out of an estimated total of 131
# Uploading ./multilabelFridgeObjects\images\103.jpg
# Uploaded ./multilabelFridgeObjects\images\103.jpg, 9 files out of an estimated total of 131
# Uploading ./multilabelFridgeObjects\images\104.jpg
# Uploaded ./multilabelFridgeObjects\images\104.jpg, 10 files out of an estimated total of 131
# Uploading ./multilabelFridgeObjects\images\105.jpg
# Uploaded ./multilabelFridgeObjects\images\105.jpg, 11 files out of an estimated total of 131
# Uploading ./multilabelFridgeObjects\images\106.jpg
# Uploaded ./multilabelFridgeObjects\images\106.jpg, 12 files out of an estimated total of 131
# Uploading ./multilabelFridgeObjects\images\107.jpg
# Uploaded ./multilabelFridgeObjects\images\107.jpg, 13 files out of an estimated total of 131
# Uploading ./multilabelFridgeObjects\images\108.jpg
# Uploaded ./multilabelFridgeObjects\images\108.jpg, 14 files out of an estimated total of 131
# Uploading ./multilabelFridgeObjects\images\109.jpg
# Uploaded ./multilabelFridgeObjects\images\109.jpg, 15 files out of an estimated total of 131
# Uploading ./multilabelFridgeObjects\images\11.jpg
# Uploaded ./multilabelFridgeObjects\images\11.jpg, 16 files out of an estimated total of 131
# Uploading ./multilabelFridgeObjects\images\110.jpg
# Uploaded ./multilabelFridgeObjects\images\110.jpg, 17 files out of an estimated total of 131
# Uploading ./multilabelFridgeObjects\images\111.jpg
# Uploaded ./multilabelFridgeObjects\images\111.jpg, 18 files out of an estimated total of 131
# Uploading ./multilabelFridgeObjects\images\112.jpg
# Uploaded ./multilabelFridgeObjects\images\112.jpg, 19 files out of an estimated total of 131
# Uploading ./multilabelFridgeObjects\images\113.jpg
# Uploaded ./multilabelFridgeObjects\images\113.jpg, 20 files out of an estimated total of 131
# Uploading ./multilabelFridgeObjects\images\114.jpg
# Uploaded ./multilabelFridgeObjects\images\114.jpg, 21 files out of an estimated total of 131
# Uploading ./multilabelFridgeObjects\images\115.jpg
# Uploaded ./multilabelFridgeObjects\images\115.jpg, 22 files out of an estimated total of 131
# Uploading ./multilabelFridgeObjects\images\116.jpg
# Uploaded ./multilabelFridgeObjects\images\116.jpg, 23 files out of an estimated total of 131
# Uploading ./multilabelFridgeObjects\images\117.jpg
# Uploaded ./multilabelFridgeObjects\images\117.jpg, 24 files out of an estimated total of 131
# Uploading ./multilabelFridgeObjects\images\118.jpg
# Uploaded ./multilabelFridgeObjects\images\118.jpg, 25 files out of an estimated total of 131
# Uploading ./multilabelFridgeObjects\images\119.jpg
# Uploaded ./multilabelFridgeObjects\images\119.jpg, 26 files out of an estimated total of 131
# Uploading ./multilabelFridgeObjects\images\12.jpg
# Uploaded ./multilabelFridgeObjects\images\12.jpg, 27 files out of an estimated total of 131
# Uploading ./multilabelFridgeObjects\images\120.jpg
# Uploaded ./multilabelFridgeObjects\images\120.jpg, 28 files out of an estimated total of 131
# Uploading ./multilabelFridgeObjects\images\121.jpg
# Uploaded ./multilabelFridgeObjects\images\121.jpg, 29 files out of an estimated total of 131
# Uploading ./multilabelFridgeObjects\images\122.jpg
# Uploaded ./multilabelFridgeObjects\images\122.jpg, 30 files out of an estimated total of 131
# Uploading ./multilabelFridgeObjects\images\123.jpg
# Uploaded ./multilabelFridgeObjects\images\123.jpg, 31 files out of an estimated total of 131
# Uploading ./multilabelFridgeObjects\images\124.jpg
# Uploaded ./multilabelFridgeObjects\images\124.jpg, 32 files out of an estimated total of 131
# Uploading ./multilabelFridgeObjects\images\125.jpg
# Uploaded ./multilabelFridgeObjects\images\125.jpg, 33 files out of an estimated total of 131
# Uploading ./multilabelFridgeObjects\images\126.jpg
# Uploaded ./multilabelFridgeObjects\images\126.jpg, 34 files out of an estimated total of 131
# Uploading ./multilabelFridgeObjects\images\127.jpg
# Uploaded ./multilabelFridgeObjects\images\127.jpg, 35 files out of an estimated total of 131
# Uploading ./multilabelFridgeObjects\images\13.jpg
# Uploaded ./multilabelFridgeObjects\images\13.jpg, 36 files out of an estimated total of 131
# Uploading ./multilabelFridgeObjects\images\14.jpg
# Uploaded ./multilabelFridgeObjects\images\14.jpg, 37 files out of an estimated total of 131
# Uploading ./multilabelFridgeObjects\images\15.jpg
# Uploaded ./multilabelFridgeObjects\images\15.jpg, 38 files out of an estimated total of 131
# Uploading ./multilabelFridgeObjects\images\16.jpg
# Uploaded ./multilabelFridgeObjects\images\16.jpg, 39 files out of an estimated total of 131
# Uploading ./multilabelFridgeObjects\images\17.jpg
# Uploaded ./multilabelFridgeObjects\images\17.jpg, 40 files out of an estimated total of 131
# Uploading ./multilabelFridgeObjects\images\18.jpg
# Uploaded ./multilabelFridgeObjects\images\18.jpg, 41 files out of an estimated total of 131
# Uploading ./multilabelFridgeObjects\images\19.jpg
# Uploaded ./multilabelFridgeObjects\images\19.jpg, 42 files out of an estimated total of 131
# Uploading ./multilabelFridgeObjects\images\2.jpg
# Uploaded ./multilabelFridgeObjects\images\2.jpg, 43 files out of an estimated total of 131
# Uploading ./multilabelFridgeObjects\images\21.jpg
# Uploaded ./multilabelFridgeObjects\images\21.jpg, 44 files out of an estimated total of 131
# Uploading ./multilabelFridgeObjects\images\22.jpg
# Uploaded ./multilabelFridgeObjects\images\22.jpg, 45 files out of an estimated total of 131
# Uploading ./multilabelFridgeObjects\images\23.jpg
# Uploaded ./multilabelFridgeObjects\images\23.jpg, 46 files out of an estimated total of 131
# Uploading ./multilabelFridgeObjects\images\24.jpg
# Uploaded ./multilabelFridgeObjects\images\24.jpg, 47 files out of an estimated total of 131
# Uploading ./multilabelFridgeObjects\images\25.jpg
# Uploaded ./multilabelFridgeObjects\images\25.jpg, 48 files out of an estimated total of 131
# Uploading ./multilabelFridgeObjects\images\26.jpg
# Uploaded ./multilabelFridgeObjects\images\26.jpg, 49 files out of an estimated total of 131
# Uploading ./multilabelFridgeObjects\images\27.jpg
# Uploaded ./multilabelFridgeObjects\images\27.jpg, 50 files out of an estimated total of 131
# Uploading ./multilabelFridgeObjects\images\28.jpg
# Uploaded ./multilabelFridgeObjects\images\28.jpg, 51 files out of an estimated total of 131
# Uploading ./multilabelFridgeObjects\images\29.jpg
# Uploaded ./multilabelFridgeObjects\images\29.jpg, 52 files out of an estimated total of 131
# Uploading ./multilabelFridgeObjects\images\3.jpg
# Uploaded ./multilabelFridgeObjects\images\3.jpg, 53 files out of an estimated total of 131
# Uploading ./multilabelFridgeObjects\images\30.jpg
# Uploaded ./multilabelFridgeObjects\images\30.jpg, 54 files out of an estimated total of 131
# Uploading ./multilabelFridgeObjects\images\31.jpg
# Uploaded ./multilabelFridgeObjects\images\31.jpg, 55 files out of an estimated total of 131
# Uploading ./multilabelFridgeObjects\images\32.jpg
# Uploaded ./multilabelFridgeObjects\images\32.jpg, 56 files out of an estimated total of 131
# Uploading ./multilabelFridgeObjects\images\33.jpg
# Uploaded ./multilabelFridgeObjects\images\33.jpg, 57 files out of an estimated total of 131
# Uploading ./multilabelFridgeObjects\images\34.jpg
# Uploaded ./multilabelFridgeObjects\images\34.jpg, 58 files out of an estimated total of 131
# Uploading ./multilabelFridgeObjects\images\35.jpg
# Uploaded ./multilabelFridgeObjects\images\35.jpg, 59 files out of an estimated total of 131
# Uploading ./multilabelFridgeObjects\images\36.jpg
# Uploaded ./multilabelFridgeObjects\images\36.jpg, 60 files out of an estimated total of 131
# Uploading ./multilabelFridgeObjects\images\37.jpg
# Uploaded ./multilabelFridgeObjects\images\37.jpg, 61 files out of an estimated total of 131
# Uploading ./multilabelFridgeObjects\images\38.jpg
# Uploaded ./multilabelFridgeObjects\images\38.jpg, 62 files out of an estimated total of 131
# Uploading ./multilabelFridgeObjects\images\39.jpg
# Uploaded ./multilabelFridgeObjects\images\39.jpg, 63 files out of an estimated total of 131
# Uploading ./multilabelFridgeObjects\images\4.jpg
# Uploaded ./multilabelFridgeObjects\images\4.jpg, 64 files out of an estimated total of 131
# Uploading ./multilabelFridgeObjects\images\40.jpg
# Uploaded ./multilabelFridgeObjects\images\40.jpg, 65 files out of an estimated total of 131
# Uploading ./multilabelFridgeObjects\images\41.jpg
# Uploaded ./multilabelFridgeObjects\images\41.jpg, 66 files out of an estimated total of 131
# Uploading ./multilabelFridgeObjects\images\42.jpg
# Uploaded ./multilabelFridgeObjects\images\42.jpg, 67 files out of an estimated total of 131
# Uploading ./multilabelFridgeObjects\images\43.jpg
# Uploaded ./multilabelFridgeObjects\images\43.jpg, 68 files out of an estimated total of 131
# Uploading ./multilabelFridgeObjects\images\44.jpg
# Uploaded ./multilabelFridgeObjects\images\44.jpg, 69 files out of an estimated total of 131
# Uploading ./multilabelFridgeObjects\images\45.jpg
# Uploaded ./multilabelFridgeObjects\images\45.jpg, 70 files out of an estimated total of 131
# Uploading ./multilabelFridgeObjects\images\46.jpg
# Uploaded ./multilabelFridgeObjects\images\46.jpg, 71 files out of an estimated total of 131
# Uploading ./multilabelFridgeObjects\images\47.jpg
# Uploaded ./multilabelFridgeObjects\images\47.jpg, 72 files out of an estimated total of 131
# Uploading ./multilabelFridgeObjects\images\48.jpg
# Uploaded ./multilabelFridgeObjects\images\48.jpg, 73 files out of an estimated total of 131
# Uploading ./multilabelFridgeObjects\images\49.jpg
# Uploaded ./multilabelFridgeObjects\images\49.jpg, 74 files out of an estimated total of 131
# Uploading ./multilabelFridgeObjects\images\5.jpg
# Uploaded ./multilabelFridgeObjects\images\5.jpg, 75 files out of an estimated total of 131
# Uploading ./multilabelFridgeObjects\images\50.jpg
# Uploaded ./multilabelFridgeObjects\images\50.jpg, 76 files out of an estimated total of 131
# Uploading ./multilabelFridgeObjects\images\51.jpg
# Uploaded ./multilabelFridgeObjects\images\51.jpg, 77 files out of an estimated total of 131
# Uploading ./multilabelFridgeObjects\images\52.jpg
# Uploaded ./multilabelFridgeObjects\images\52.jpg, 78 files out of an estimated total of 131
# Uploading ./multilabelFridgeObjects\images\53.jpg
# Uploaded ./multilabelFridgeObjects\images\53.jpg, 79 files out of an estimated total of 131
# Uploading ./multilabelFridgeObjects\images\54.jpg
# Uploaded ./multilabelFridgeObjects\images\54.jpg, 80 files out of an estimated total of 131
# Uploading ./multilabelFridgeObjects\images\55.jpg
# Uploaded ./multilabelFridgeObjects\images\55.jpg, 81 files out of an estimated total of 131
# Uploading ./multilabelFridgeObjects\images\56.jpg
# Uploaded ./multilabelFridgeObjects\images\56.jpg, 82 files out of an estimated total of 131
# Uploading ./multilabelFridgeObjects\images\57.jpg
# Uploaded ./multilabelFridgeObjects\images\57.jpg, 83 files out of an estimated total of 131
# Uploading ./multilabelFridgeObjects\images\58.jpg
# Uploaded ./multilabelFridgeObjects\images\58.jpg, 84 files out of an estimated total of 131
# Uploading ./multilabelFridgeObjects\images\59.jpg
# Uploaded ./multilabelFridgeObjects\images\59.jpg, 85 files out of an estimated total of 131
# Uploading ./multilabelFridgeObjects\images\6.jpg
# Uploaded ./multilabelFridgeObjects\images\6.jpg, 86 files out of an estimated total of 131
# Uploading ./multilabelFridgeObjects\images\60.jpg
# Uploaded ./multilabelFridgeObjects\images\60.jpg, 87 files out of an estimated total of 131
# Uploading ./multilabelFridgeObjects\images\61.jpg
# Uploaded ./multilabelFridgeObjects\images\61.jpg, 88 files out of an estimated total of 131
# Uploading ./multilabelFridgeObjects\images\62.jpg
# Uploaded ./multilabelFridgeObjects\images\62.jpg, 89 files out of an estimated total of 131
# Uploading ./multilabelFridgeObjects\images\63.jpg
# Uploaded ./multilabelFridgeObjects\images\63.jpg, 90 files out of an estimated total of 131
# Uploading ./multilabelFridgeObjects\images\64.jpg
# Uploaded ./multilabelFridgeObjects\images\64.jpg, 91 files out of an estimated total of 131
# Uploading ./multilabelFridgeObjects\images\65.jpg
# Uploaded ./multilabelFridgeObjects\images\65.jpg, 92 files out of an estimated total of 131
# Uploading ./multilabelFridgeObjects\images\66.jpg
# Uploaded ./multilabelFridgeObjects\images\66.jpg, 93 files out of an estimated total of 131
# Uploading ./multilabelFridgeObjects\images\67.jpg
# Uploaded ./multilabelFridgeObjects\images\67.jpg, 94 files out of an estimated total of 131
# Uploading ./multilabelFridgeObjects\images\68.jpg
# Uploaded ./multilabelFridgeObjects\images\68.jpg, 95 files out of an estimated total of 131
# Uploading ./multilabelFridgeObjects\images\69.jpg
# Uploaded ./multilabelFridgeObjects\images\69.jpg, 96 files out of an estimated total of 131
# Uploading ./multilabelFridgeObjects\images\7.jpg
# Uploaded ./multilabelFridgeObjects\images\7.jpg, 97 files out of an estimated total of 131
# Uploading ./multilabelFridgeObjects\images\70.jpg
# Uploaded ./multilabelFridgeObjects\images\70.jpg, 98 files out of an estimated total of 131
# Uploading ./multilabelFridgeObjects\images\71.jpg
# Uploaded ./multilabelFridgeObjects\images\71.jpg, 99 files out of an estimated total of 131
# Uploading ./multilabelFridgeObjects\images\72.jpg
# Uploaded ./multilabelFridgeObjects\images\72.jpg, 100 files out of an estimated total of 131
# Uploading ./multilabelFridgeObjects\images\73.jpg
# Uploaded ./multilabelFridgeObjects\images\73.jpg, 101 files out of an estimated total of 131
# Uploading ./multilabelFridgeObjects\images\74.jpg
# Uploaded ./multilabelFridgeObjects\images\74.jpg, 102 files out of an estimated total of 131
# Uploading ./multilabelFridgeObjects\images\75.jpg
# Uploaded ./multilabelFridgeObjects\images\75.jpg, 103 files out of an estimated total of 131
# Uploading ./multilabelFridgeObjects\images\76.jpg
# Uploaded ./multilabelFridgeObjects\images\76.jpg, 104 files out of an estimated total of 131
# Uploading ./multilabelFridgeObjects\images\77.jpg
# Uploaded ./multilabelFridgeObjects\images\77.jpg, 105 files out of an estimated total of 131
# Uploading ./multilabelFridgeObjects\images\78.jpg
# Uploaded ./multilabelFridgeObjects\images\78.jpg, 106 files out of an estimated total of 131
# Uploading ./multilabelFridgeObjects\images\79.jpg
# Uploaded ./multilabelFridgeObjects\images\79.jpg, 107 files out of an estimated total of 131
# Uploading ./multilabelFridgeObjects\images\8.jpg
# Uploaded ./multilabelFridgeObjects\images\8.jpg, 108 files out of an estimated total of 131
# Uploading ./multilabelFridgeObjects\images\80.jpg
# Uploaded ./multilabelFridgeObjects\images\80.jpg, 109 files out of an estimated total of 131
# Uploading ./multilabelFridgeObjects\images\81.jpg
# Uploaded ./multilabelFridgeObjects\images\81.jpg, 110 files out of an estimated total of 131
# Uploading ./multilabelFridgeObjects\images\82.jpg
# Uploaded ./multilabelFridgeObjects\images\82.jpg, 111 files out of an estimated total of 131
# Uploading ./multilabelFridgeObjects\images\84.jpg
# Uploaded ./multilabelFridgeObjects\images\84.jpg, 112 files out of an estimated total of 131
# Uploading ./multilabelFridgeObjects\images\85.jpg
# Uploaded ./multilabelFridgeObjects\images\85.jpg, 113 files out of an estimated total of 131
# Uploading ./multilabelFridgeObjects\images\89.jpg
# Uploaded ./multilabelFridgeObjects\images\89.jpg, 114 files out of an estimated total of 131
# Uploading ./multilabelFridgeObjects\images\9.jpg
# Uploaded ./multilabelFridgeObjects\images\9.jpg, 115 files out of an estimated total of 131
# Uploading ./multilabelFridgeObjects\images\93.jpg
# Uploaded ./multilabelFridgeObjects\images\93.jpg, 116 files out of an estimated total of 131
# Uploading ./multilabelFridgeObjects\images\86.jpg
# Uploaded ./multilabelFridgeObjects\images\86.jpg, 117 files out of an estimated total of 131
# Uploading ./multilabelFridgeObjects\images\92.jpg
# Uploaded ./multilabelFridgeObjects\images\92.jpg, 118 files out of an estimated total of 131
# Uploading ./multilabelFridgeObjects\images\94.jpg
# Uploaded ./multilabelFridgeObjects\images\94.jpg, 119 files out of an estimated total of 131
# Uploading ./multilabelFridgeObjects\images\83.jpg
# Uploaded ./multilabelFridgeObjects\images\83.jpg, 120 files out of an estimated total of 131
# Uploading ./multilabelFridgeObjects\images\91.jpg
# Uploaded ./multilabelFridgeObjects\images\91.jpg, 121 files out of an estimated total of 131
# Uploading ./multilabelFridgeObjects\images\95.jpg
# Uploaded ./multilabelFridgeObjects\images\95.jpg, 122 files out of an estimated total of 131
# Uploading ./multilabelFridgeObjects\images\96.jpg
# Uploaded ./multilabelFridgeObjects\images\96.jpg, 123 files out of an estimated total of 131
# Uploading ./multilabelFridgeObjects\images\88.jpg
# Uploaded ./multilabelFridgeObjects\images\88.jpg, 124 files out of an estimated total of 131
# Uploading ./multilabelFridgeObjects\images\99.jpg
# Uploaded ./multilabelFridgeObjects\images\99.jpg, 125 files out of an estimated total of 131
# Uploading ./multilabelFridgeObjects\images\98.jpg
# Uploaded ./multilabelFridgeObjects\images\98.jpg, 126 files out of an estimated total of 131
# Uploading ./multilabelFridgeObjects\images\87.jpg
# Uploaded ./multilabelFridgeObjects\images\87.jpg, 127 files out of an estimated total of 131
# Uploading ./multilabelFridgeObjects\images\97.jpg
# Uploaded ./multilabelFridgeObjects\images\97.jpg, 128 files out of an estimated total of 131
# Uploading ./multilabelFridgeObjects\images\90.jpg
# Uploaded ./multilabelFridgeObjects\images\90.jpg, 129 files out of an estimated total of 131
# Uploading ./multilabelFridgeObjects\images\20.jpg
# Uploaded ./multilabelFridgeObjects\images\20.jpg, 130 files out of an estimated total of 131
# Uploading ./multilabelFridgeObjects\images\128.jpg
# Uploaded ./multilabelFridgeObjects\images\128.jpg, 131 files out of an estimated total of 131
# Uploaded 131 files
# $AZUREML_DATAREFERENCE_27a438663a1c4da1a42bf06a858f5729

# %% [markdown]
# Finally, we need to create an Azure ML [Dataset](https://docs.microsoft.com/en-us/azure/machine-learning/concept-azure-machine-learning-architecture#datasets-and-datastores) from the data we uploaded to the Datastore. We create one dataset for training and one for validation.

# %%
from azureml.contrib.dataset.labeled_dataset import _LabeledDatasetFactory, LabeledDatasetTask
from azureml.core import Dataset

training_dataset_name = 'multilabelFridgeObjectsTrainingDataset'
if training_dataset_name in ws.datasets:
    training_dataset = ws.datasets.get(training_dataset_name)
    print('Found the training dataset', training_dataset_name)
else:
    # create training dataset
    training_dataset = _LabeledDatasetFactory.from_json_lines(
        task=LabeledDatasetTask.IMAGE_MULTI_LABEL_CLASSIFICATION, path=ds.path('multilabelFridgeObjects/train_annotations.jsonl'))
    training_dataset = training_dataset.register(workspace=ws, name=training_dataset_name)
    
# create validation dataset
validation_dataset_name = "multilabelFridgeObjectsValidationDataset"
if validation_dataset_name in ws.datasets:
    validation_dataset = ws.datasets.get(validation_dataset_name)
    print('Found the validation dataset', validation_dataset_name)
else:
    validation_dataset = _LabeledDatasetFactory.from_json_lines(
        task=LabeledDatasetTask.IMAGE_MULTI_LABEL_CLASSIFICATION, path=ds.path('multilabelFridgeObjects/validation_annotations.jsonl'))
    validation_dataset = validation_dataset.register(workspace=ws, name=validation_dataset_name)
    
    
print("Training dataset name: " + training_dataset.name)
print("Validation dataset name: " + validation_dataset.name)
# Out:
# Training dataset name: multilabelFridgeObjectsTrainingDataset
# Validation dataset name: multilabelFridgeObjectsValidationDataset

# %% [markdown]
# Validation dataset is optional. If no validation dataset is specified, 20% of your training data will be used for validation.
#
# This is what the training dataset looks like

# %%
training_dataset.to_pandas_dataframe()

# %% [markdown]
# ## Configuring your AutoML Vision run
# AutoML allows you to easily train models for Image Classification, Object Detection & Instance Segmentation on your image data. You can control the model algorithm to be used, specify hyperparameter values for your model as well as perform a sweep across the hyperparameter space to generate an optimal model. Parameters for configuring your AutoML Vision run are specified using the 'AutoMLVisionConfig'.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# When using AutoML Vision, you need to specify the model algorithm/s using the model_name parameter. You can either specify a single model or choose between multiple.
# ### Currently supported model algorithms:
# <ul>
# <li><b>Image Classification (multi-class and multi-label):</b> 'resnet18', 'resnet50', 'mobilenetv2', 'seresnext'</li>
# <li><b>Object Detection: </b>'yolov5', 'fasterrcnn_resnet50_fpn', 'fasterrcnn_resnet34_fpn', 'fasterrcnn_resnet18_fpn', 'retinanet_resnet50_fpn'</li>
# <li><b>Instance segmentation: </b>'maskrcnn_resnet50_fpn'</li>
# </ul>
#
# ### Hyperparameter sweeping for your AutoML Vision models
# In this example, we use the AutoMLVisionConfig to train an Object Detection model using yolov5 and fasterrcnn_resnet50_fpn, both of which are pretrained on COCO, a large-scale object detection, segmentation, and captioning dataset that contains over 200K labeled images with over 80 label cateogories.
#
# With AutoML Vision, you can perform a hyperparameter sweep over a defined parameter space, to find the optimal model. In this example, we sweep over the hyperparameters for each algorithm, choosing from a range of values for learning_rate, batch_size, etc, to generate a model with the optimal 'mean_average_precision'. If hyperparameter values are not specified, then default values are used for the specified algorithm.
#
# We use Random Sampling to pick samples from this parameter space and try a total of 10 iterations with these different samples, running 4 iterations at a time on our compute target, which has been previously set up using 4 nodes.
#
# We also leverage the Bandit early termination policy that terminates poor performing configs (those that are not within 20% slack of the best perfroming config), thus significantly saving compute resources.

# %%
from azureml.train.automl import AutoMLVisionConfig
from azureml.train.hyperdrive import GridParameterSampling, RandomParameterSampling, BayesianParameterSampling
from azureml.train.hyperdrive import BanditPolicy, HyperDriveConfig, PrimaryMetricGoal
from azureml.train.hyperdrive import choice, uniform

parameter_space = {
    'model': choice(
        {
            'model_name': 'seresnext',
            'learning_rate': uniform(0.0001, 0.001)
        },
        {
            'model_name': 'resnet50',
            'learning_rate': uniform(0.0001, 0.001)
        }
    )
}

tuning_settings = {
    'iterations': 10, 
    'max_concurrent_iterations': 4, 
    'hyperparameter_sampling': RandomParameterSampling(parameter_space),  
    'policy': BanditPolicy(evaluation_interval=2, slack_factor=0.2, delay_evaluation=6),
    'scenario': 'Vision-Candidate' # Only needed until cond. HP changes are in prod
}


automl_vision_config = AutoMLVisionConfig(task='image-multi-labeling',
                                          compute_target=compute_target,
                                          training_data=training_dataset,
                                          primary_metric='iou',
                                          **tuning_settings)
# Out:
# WARNING - scenario is an internal parameter that should not be used for regular experiments.

# %% [markdown]
# ### Using default hyperparameter values for the specified algorithm
# In the example above, we saw how you can perfrom a hyperparameter sweep across multiple model algorithms when using AutoML Vision. If instead, you wish to use the default hyperparameter values for a given algorithm (say yolov5), you can specify the config for your Vision runs as follows -

# %%
automl_vision_config_default_yolov5 = AutoMLVisionConfig(
                                          task='image-object-detection',
                                          compute_target=compute_target,
                                          training_data=training_dataset,
                                          hyperparameter_sampling=GridParameterSampling({'model_name': choice('yolov5')}))

# %% [markdown]
# ## Submitting an AutoML Vision run
# Once you've created the config settings for your run, you can submit an AutoML vision run using the config in order to train a vision model using your training dataset and generate the optimal model for your scenario.

# %%
from azureml.core import Environment
import urllib
import json
download_url = 'https://curatedenvironments.blob.core.windows.net/prerelease/Candidate/AzureML-AutoML-DNN-Vision-GPU/envdef.json'
data_file = './envdef.json'
urllib.request.urlretrieve(download_url, filename=data_file)
with open(data_file, 'r') as env_f:
    e = json.loads(env_f.read())
    e['name'] = "AutoML-DNN-Vision-GPU-Candidate"
    
automl_env = './azureml_environment.json'
with open(automl_env, 'w') as automl_env_f:
    automl_env_f.write(json.dumps(e))
    
env = Environment.load_from_directory('.')
env.register(ws)
# Out:
# {
#     "databricks": {
#         "eggLibraries": [],
#         "jarLibraries": [],
#         "mavenLibraries": [],
#         "pypiLibraries": [],
#         "rcranLibraries": []
#     },
#     "docker": {
#         "arguments": [],
#         "baseDockerfile": null,
#         "baseImage": "mcr.microsoft.com/azureml/openmpi3.1.2-cuda10.0-cudnn7-ubuntu16.04:20210331.v1",
#         "baseImageRegistry": null,
#         "enabled": true,
#         "platform": {
#             "architecture": "amd64",
#             "os": "Linux"
#         },
#         "sharedVolumes": true,
#         "shmSize": "16g"
#     },
#     "environmentVariables": {},
#     "inferencingStackVersion": null,
#     "name": "AutoML-DNN-Vision-GPU-Candidate",
#     "python": {
#         "baseCondaEnvironment": null,
#         "condaDependencies": {
#             "channels": [
#                 "conda-forge"
#             ],
#             "dependencies": [
#                 "python=3.7",
#                 {
#                     "pip": [
#                         "--extra-index-url https://azuremlsdktestpypi.azureedge.net/sdk-release/Candidate/604C89A437BA41BD942B4F46D9A3591D",
#                         "azureml-core==1.26.0a3",
#                         "azureml-dataset-runtime==1.26.0a3",
#                         "azureml-contrib-dataset==1.26.0a3",
#                         "azureml-telemetry==1.26.0a3",
#                         "azureml-automl-core==1.26.0a3",
#                         "azureml-automl-runtime==1.26.0a3",
#                         "azureml-train-automl-client==1.26.0a3",
#                         "azureml-defaults==1.26.0a3",
#                         "azureml-interpret==1.26.0a3",
#                         "azureml-train-automl-runtime==1.26.0a3",
#                         "azureml-train-automl==1.26.0a3",
#                         "azureml-contrib-automl-dnn-vision==1.26.0a3"
#                     ]
#                 },
#                 "numpy==1.18.5"
#             ],
#             "name": "azureml_48f8fdfe86ad65b8620729c2ae97a213"
#         },
#         "condaDependenciesFile": null,
#         "interpreterPath": "python",
#         "userManagedDependencies": false
#     },
#     "r": null,
#     "spark": {
#         "packages": [],
#         "precachePackages": true,
#         "repositories": []
#     },
#     "version": "2"
# }

# %%
automl_vision_run = experiment.submit(automl_vision_config)
# Out:
# Submitting remote run.
# <table style="width:100%"><tr><th>Experiment</th><th>Id</th><th>Type</th><th>Status</th><th>Details Page</th><th>Docs Page</th></tr><tr><td>automl-vision-notebook</td><td>AutoML_a496c8d2-3237-4894-ae3a-dd54293dc9f2</td><td>automl</td><td>NotStarted</td><td><a href="https://ml.azure.com/runs/AutoML_a496c8d2-3237-4894-ae3a-dd54293dc9f2?wsid=/subscriptions/dbd697c3-ef40-488f-83e6-5ad4dfb78f9b/resourcegroups/alwangeu21/workspaces/alwangeu21&amp;tid=72f988bf-86f1-41af-91ab-2d7cd011db47" target="_blank" rel="noopener">Link to Azure Machine Learning studio</a></td><td><a href="https://docs.microsoft.com/en-us/python/api/overview/azure/ml/intro?view=azure-ml-py" target="_blank" rel="noopener">Link to Documentation</a></td></tr></table>

# %%
automl_vision_run.wait_for_completion(wait_post_processing=True)
# Out:
# {'runId': 'AutoML_a496c8d2-3237-4894-ae3a-dd54293dc9f2',
#  'target': 'nc6cluster',
#  'status': 'Completed',
#  'startTimeUtc': '2021-04-08T19:49:11.804432Z',
#  'endTimeUtc': '2021-04-08T20:02:50.289331Z',
#  'properties': {'num_iterations': '1',
#   'training_type': 'TrainFull',
#   'acquisition_function': 'EI',
#   'primary_metric': 'iou',
#   'train_split': '0',
#   'acquisition_parameter': '0',
#   'num_cross_validation': None,
#   'target': 'nc6cluster',
#   'AMLSettingsJsonString': '{"path":null,"name":"automl-vision-notebook","subscription_id":"dbd697c3-ef40-488f-83e6-5ad4dfb78f9b","resource_group":"alwangeu21","workspace_name":"alwangeu21","region":"eastus","compute_target":"nc6cluster","spark_service":null,"azure_service":"remote","many_models":false,"pipeline_fetch_max_batch_size":1,"enable_batch_run":false,"enable_run_restructure":false,"iterations":1,"primary_metric":"iou","task_type":"image-multi-labeling","data_script":null,"test_size":0.0,"validation_size":0.0,"n_cross_validations":null,"y_min":null,"y_max":null,"num_classes":null,"featurization":"off","_ignore_package_version_incompatibilities":false,"is_timeseries":false,"max_cores_per_iteration":1,"max_concurrent_iterations":1,"iteration_timeout_minutes":null,"mem_in_mb":null,"enforce_time_on_windows":true,"experiment_timeout_minutes":8640,"experiment_exit_score":null,"whitelist_models":null,"blacklist_algos":["TensorFlowDNN","TensorFlowLinearRegressor"],"supported_models":[],"private_models":[],"auto_blacklist":true,"blacklist_samples_reached":false,"exclude_nan_labels":true,"verbosity":20,"_debug_log":"azureml_automl.log","show_warnings":false,"model_explainability":true,"service_url":null,"sdk_url":null,"sdk_packages":null,"enable_onnx_compatible_models":false,"enable_split_onnx_featurizer_estimator_models":false,"vm_type":"STANDARD_NC6","telemetry_verbosity":20,"send_telemetry":true,"enable_dnn":true,"scenario":"Vision-Candidate","environment_label":null,"save_mlflow":false,"force_text_dnn":false,"enable_feature_sweeping":true,"enable_early_stopping":false,"early_stopping_n_iters":10,"dataset_id":"03037594-122a-4dab-a6b6-5f394565d996","hyperdrive_config":{"max_total_jobs":10,"max_concurrent_jobs":4,"generator_config":{"name":"RANDOM","parameter_space":"{\\"model\\": [\\"choice\\", [[{\\"model_name\\": \\"seresnext\\", \\"learning_rate\\": [\\"uniform\\", [0.0001, 0.001]]}, {\\"model_name\\": \\"resnet50\\", \\"learning_rate\\": [\\"uniform\\", [0.0001, 0.001]]}]]]}"},"policy_config":{"name":"Bandit","properties":{"evaluation_interval":2,"delay_evaluation":6,"slack_factor":0.2}}},"validation_dataset_id":null,"metrics":null,"enable_metric_confidence":false,"enable_ensembling":false,"enable_stack_ensembling":false,"ensemble_iterations":null,"enable_tf":false,"enable_subsampling":false,"subsample_seed":null,"enable_nimbusml":false,"enable_streaming":false,"force_streaming":false,"track_child_runs":true,"allowed_private_models":[],"label_column_name":"label","weight_column_name":null,"cv_split_column_names":null,"enable_local_managed":false,"_local_managed_run_id":null,"cost_mode":1,"lag_length":0,"metric_operation":"maximize","preprocess":false}',
#   'DataPrepJsonString': '{\\"training_data\\": {\\"datasetId\\": \\"03037594-122a-4dab-a6b6-5f394565d996\\"}, \\"datasets\\": 0}',
#   'EnableSubsampling': 'False',
#   'runTemplate': 'AutoML',
#   'azureml.runsource': 'automl',
#   'display_task_type': 'image-multi-labeling',
#   'dependencies_versions': '{"azureml-model-management-sdk": "1.0.1b6.post1", "azureml-contrib-automl-dnn-vision": "1.19.0", "azureml-train": "0.1.0.34635915", "azureml-train-restclients-hyperdrive": "0.1.0.34635915", "azureml-train-core": "0.1.0.34635915", "azureml-train-automl": "0.1.0.34635915", "azureml-train-automl-runtime": "0.1.0.34635915", "azureml-train-automl-client": "0.1.0.34635915", "azureml-telemetry": "0.1.0.34635915", "azureml-interpret": "0.1.0.34635915", "azureml-defaults": "0.1.0.34635915", "azureml-dataset-runtime": "0.1.0.34635915", "azureml-dataprep": "2.13.2", "azureml-dataprep-rslex": "1.11.2", "azureml-dataprep-native": "32.0.0", "azureml-core": "0.1.0.34635915", "azureml-contrib-dataset": "0.1.0.34635915", "azureml-automl-runtime": "0.1.0.34635915", "azureml-automl-core": "0.1.0.34635915"}',
#   '_aml_system_scenario_identification': 'Remote.Parent',
#   'ClientType': 'SDK',
#   'environment_cpu_name': 'AutoML-DNN-Vision-GPU-Candidate',
#   'environment_cpu_label': 'Latest',
#   'environment_gpu_name': 'AutoML-DNN-Vision-GPU-Candidate',
#   'environment_gpu_label': 'Latest',
#   'root_attribution': 'automl',
#   'attribution': 'AutoML',
#   'Orchestrator': 'AutoML',
#   'CancelUri': 'https://eastus.experiments.azureml.net/jasmine/v1.0/subscriptions/dbd697c3-ef40-488f-83e6-5ad4dfb78f9b/resourceGroups/alwangeu21/providers/Microsoft.MachineLearningServices/workspaces/alwangeu21/experimentids/72c83af6-b2dc-4553-a3b4-f78bc98223e0/cancel/AutoML_a496c8d2-3237-4894-ae3a-dd54293dc9f2',
#   'azureml.git.repository_uri': 'https://github.com/swatig007/automlVision.git',
#   'mlflow.source.git.repoURL': 'https://github.com/swatig007/automlVision.git',
#   'azureml.git.branch': 'alwang/multiclass',
#   'mlflow.source.git.branch': 'alwang/multiclass',
#   'azureml.git.commit': 'f69e64dbcd9c9bd9090a8a32a4a2a680e85befa9',
#   'mlflow.source.git.commit': 'f69e64dbcd9c9bd9090a8a32a4a2a680e85befa9',
#   'azureml.git.dirty': 'True',
#   'ClientSdkVersion': '1.26.0a3',
#   'snapshotId': '00000000-0000-0000-0000-000000000000'},
#  'inputDatasets': [{'dataset': {'id': '03037594-122a-4dab-a6b6-5f394565d996'}, 'consumptionDetails': {'type': 'RunInput', 'inputName': 'training_data', 'mechanism': 'Direct'}}],
#  'outputDatasets': [],
#  'logFiles': {},
#  'submittedBy': 'Allen Wang'}

# %% [markdown]
# ## Register the optimal model from the AutoML Vision run
# Once the run completes, we can register the model that was created from the best run (configuration that resulted in the best primary metric)

# %%
#Register the model from the best run
#from azureml.train.automl.run import AutoMLRun
#automl_vision_run = AutoMLRun(experiment, 'AutoML_2ebc167a-07b2-47aa-9b8b-f618786fea9f')

best_child_run = automl_vision_run.get_best_child()
model_name = best_child_run.properties['model_name']
model = best_child_run.register_model(model_name = model_name, model_path='outputs/model.pt')

# %% [markdown]
# ## Deploy model as a web service
# Once you have your trained model, you can deploy the model on Azure. You can deploy your trained model as a web service on Azure Container Instances ([ACI](https://docs.microsoft.com/en-us/azure/machine-learning/how-to-deploy-azure-container-instance)) or Azure Kubernetes Service ([AKS](https://docs.microsoft.com/en-us/azure/machine-learning/how-to-deploy-azure-kubernetes-service)). ACI is the perfect option for testing deployments, while AKS is better suited for for high-scale, production usage.
# In this tutorial, we will deploy the model as a web service in AKS.

# %% [markdown]
# You will need to first create an AKS compute cluster, or use an existing AKS cluster.

# %%
from azureml.core.compute import ComputeTarget, AksCompute
from azureml.exceptions import ComputeTargetException

# Choose a name for your cluster
aks_name = "raduko-aks-gpu"

# Check to see if the cluster already exists
try:
    aks_target = ComputeTarget(workspace=ws, name=aks_name)
    print('Found existing compute target')
except ComputeTargetException:
    print('Creating a new compute target...')
    # Provision AKS cluster with GPU machine
    prov_config = AksCompute.provisioning_configuration(vm_size="STANDARD_NC6", 
                                                        location="eastus2")
    #prov_config = AksCompute.provisioning_configuration()
    # Create the cluster
    aks_target = ComputeTarget.create(workspace=ws, 
                                      name=aks_name, 
                                      provisioning_configuration=prov_config)

    aks_target.wait_for_completion(show_output=True)
# Out:
# Found existing compute target

# %% [markdown]
# Next, you will need to define the inference configuration, that describes how to set up the web-service containing your model. You can use the scoring script and the environment from the training run in your inference config.
# You can then deploy the model as an AKS web service.

# %%
#Deploy the model from the best run as an AKS web service
from azureml.core.model import InferenceConfig
from azureml.core.webservice import AksWebservice
from azureml.core.webservice import Webservice
from azureml.core.model import Model
from azureml.core.environment import Environment

best_child_run.download_file('outputs/scoring_file_v_1_0_0.py', output_file_path='score.py')
environment = best_child_run.get_environment()
inference_config = InferenceConfig(entry_script='score.py', environment=environment)

aks_config = AksWebservice.deploy_configuration(autoscale_enabled=True,                                                    
                                                    cpu_cores=1,
                                                    memory_gb=50,
                                                    enable_app_insights=True)

aks_service = Model.deploy(ws,
                           models=[model],
                           inference_config=inference_config,
                           deployment_config=aks_config,
                           deployment_target=aks_target,
                           name='automl-vision-raduko-test',
                           overwrite=True)
aks_service.wait_for_deployment(show_output=True)
print(aks_service.state)
# Out:
# Tips: You can try get_logs(): https://aka.ms/debugimage#dockerlog or local deployment: https://aka.ms/debugimage#debug-locally to debug if deployment takes longer than 10 minutes.
# Running
# 2021-04-08 13:13:56-07:00 Creating Container Registry if not exists.
# 2021-04-08 13:13:56-07:00 Registering the environment.
# 2021-04-08 13:13:59-07:00 Use the existing image..
# 2021-04-08 13:14:03-07:00 Checking the status of deployment automl-vision-raduko-test..
# 2021-04-08 13:14:25-07:00 Checking the status of inference endpoint automl-vision-raduko-test.
# Succeeded
# AKS service creation operation finished, operation "Succeeded"
# Healthy

# %% [markdown]
# ## Test the web service
# Finally, let's test our deployed web service to predict new images. You can pass in any image. In this case, we'll use a random image from the dataset and pass it to te scoring URI.

# %%
import requests
from IPython.display import Image

# URL for the web service
scoring_uri = aks_service.scoring_uri

# If the service is authenticated, set the key or token
key, _ = aks_service.get_keys()

sample_image = './test_image.jpg'

# Load image data
data = open(sample_image, 'rb').read()

# Set the content type
headers = {'Content-Type': 'application/octet-stream'}

# If authentication is enabled, set the authorization header
headers['Authorization'] = f'Bearer {key}'

# Make the request and display the response
resp = requests.post(scoring_uri, data, headers=headers)
print(resp.text)

Image(filename=sample_image)
# Out:
# {"filename": "/tmp/tmpamh9_t_j", "probs": [0.6394238471984863, 0.6789912581443787, 0.6502765417098999, 0.639064610004425], "labels": ["can", "carton", "milk_bottle", "water_bottle"]}
